# %%
import base64
import re
import pandas as pd
import os
from huggingface_hub import InferenceClient
from natsort import natsorted
import numpy as np
import time
folder_path = "archive/images/"
base64_images = [
    base64.b64encode(open(os.path.join(folder_path, f), "rb").read()).decode('utf-8')
    for f in natsorted(os.listdir(folder_path))
    if os.path.isfile(os.path.join(folder_path, f))
]
output_gemma = []
output_qwen = []
print(f"Закодировано изображений: {len(base64_images)}")
# Out:
# Закодировано изображений: 39

# %% [markdown]
# ### Обращение к модели dima806/facial_emotions_image_detection

# %%
client = InferenceClient(
    provider="hf-inference",
    api_key=os.environ["HF_TOKEN"],
)
output = []
for image in os.listdir(folder_path):
    output = output + client.image_classification(folder_path + image, model="dima806/facial_emotions_image_detection")
output
# Out:
# [ImageClassificationOutputElement(label='neutral', score=0.7460079789161682),
#  ImageClassificationOutputElement(label='sad', score=0.1032661572098732),
#  ImageClassificationOutputElement(label='fear', score=0.058445461094379425),
#  ImageClassificationOutputElement(label='happy', score=0.04335441067814827),
#  ImageClassificationOutputElement(label='angry', score=0.03251199424266815),
#  ImageClassificationOutputElement(label='fear', score=0.6285816431045532),
#  ImageClassificationOutputElement(label='surprise', score=0.2845604121685028),
#  ImageClassificationOutputElement(label='angry', score=0.03126480057835579),
#  ImageClassificationOutputElement(label='happy', score=0.0232162494212389),
#  ImageClassificationOutputElement(label='sad', score=0.019774287939071655),
#  ImageClassificationOutputElement(label='neutral', score=0.7392191290855408),
#  ImageClassificationOutputElement(label='angry', score=0.09016966074705124),
#  ImageClassificationOutputElement(label='sad', score=0.06350474059581757),
#  ImageClassificationOutputElement(label='happy', score=0.0584430918097496),
#  ImageClassificationOutputElement(label='fear', score=0.02782898209989071),
#  ImageClassificationOutputElement(label='fear', score=0.6615146994590759),
#  ImageClassificationOutputElement(label='surprise', score=0.17740580439567566),
#  ImageClassificationOutputElement(label='angry', score=0.08268677443265915),
#  ImageClassificationOutputElement(label='happy', score=0.042202286422252655),
#  ImageClassificationOutputElement(label='sad', score=0.015669023618102074),
#  ImageClassificationOutputElement(label='sad', score=0.4391707181930542),
#  ImageClassificationOutputElement(label='neutral', score=0.2790817618370056),
#  ImageClassificationOutputElement(label='happy', score=0.09616556018590927),
#  ImageClassificationOutputElement(label='fear', score=0.07756810635328293),
#  ImageClassificationOutputElement(label='angry', score=0.06453030556440353),
#  ImageClassificationOutputElement(label='neutral', score=0.3810819685459137),
#  ImageClassificationOutputElement(label='sad', score=0.3544166386127472),
#  ImageClassificationOutputElement(label='fear', score=0.1470920741558075),
#  ImageClassificationOutputElement(label='happy', score=0.05636444687843323),
#  ImageClassificationOutputElement(label='angry', score=0.02664545737206936),
#  ImageClassificationOutputElement(label='happy', score=0.4774619936943054),
#  ImageClassificationOutputElement(label='sad', score=0.2833298444747925),
#  ImageClassificationOutputElement(label='neutral', score=0.1524781882762909),
#  ImageClassificationOutputElement(label='angry', score=0.03043629787862301),
#  ImageClassificationOutputElement(label='fear', score=0.020801464095711708),
#  ImageClassificationOutputElement(label='neutral', score=0.5894324779510498),
#  ImageClassificationOutputElement(label='sad', score=0.20433691143989563),
#  ImageClassificationOutputElement(label='happy', score=0.08376003801822662),
#  ImageClassificationOutputElement(label='angry', score=0.059295088052749634),
#  ImageClassificationOutputElement(label='fear', score=0.02725379168987274),
#  ImageClassificationOutputElement(label='neutral', score=0.31410735845565796),
#  ImageClassificationOutputElement(label='happy', score=0.27056577801704407),
#  ImageClassificationOutputElement(label='sad', score=0.25360313057899475),
#  ImageClassificationOutputElement(label='surprise', score=0.058893490582704544),
#  ImageClassificationOutputElement(label='fear', score=0.0401567779481411),
#  ImageClassificationOutputElement(label='sad', score=0.41770967841148376),
#  ImageClassificationOutputElement(label='angry', score=0.31565970182418823),
#  ImageClassificationOutputElement(label='fear', score=0.08695528656244278),
#  ImageClassificationOutputElement(label='happy', score=0.07650530338287354),
#  ImageClassificationOutputElement(label='neutral', score=0.05640467628836632),
#  ImageClassificationOutputElement(label='surprise', score=0.9523983001708984),
#  ImageClassificationOutputElement(label='angry', score=0.020990973338484764),
#  ImageClassificationOutputElement(label='fear', score=0.012738730758428574),
#  ImageClassificationOutputElement(label='happy', score=0.006782909389585257),
#  ImageClassificationOutputElement(label='disgust', score=0.0028203034307807684),
#  ImageClassificationOutputElement(label='angry', score=0.21543654799461365),
#  ImageClassificationOutputElement(label='sad', score=0.21090364456176758),
#  ImageClassificationOutputElement(label='neutral', score=0.18839946389198303),
#  ImageClassificationOutputElement(label='fear', score=0.18815846741199493),
#  ImageClassificationOutputElement(label='happy', score=0.15107779204845428),
#  ImageClassificationOutputElement(label='sad', score=0.42085161805152893),
#  ImageClassificationOutputElement(label='neutral', score=0.298071950674057),
#  ImageClassificationOutputElement(label='fear', score=0.20372816920280457),
#  ImageClassificationOutputElement(label='angry', score=0.03437672182917595),
#  ImageClassificationOutputElement(label='happy', score=0.017364252358675003),
#  ImageClassificationOutputElement(label='sad', score=0.5163913369178772),
#  ImageClassificationOutputElement(label='neutral', score=0.28293952345848083),
#  ImageClassificationOutputElement(label='fear', score=0.10777866095304489),
#  ImageClassificationOutputElement(label='angry', score=0.04011527821421623),
#  ImageClassificationOutputElement(label='happy', score=0.0259663425385952),
#  ImageClassificationOutputElement(label='happy', score=0.9752674698829651),
#  ImageClassificationOutputElement(label='neutral', score=0.006009737495332956),
#  ImageClassificationOutputElement(label='surprise', score=0.005982324481010437),
#  ImageClassificationOutputElement(label='sad', score=0.005274144001305103),
#  ImageClassificationOutputElement(label='fear', score=0.002984860446304083),
#  ImageClassificationOutputElement(label='sad', score=0.6172611713409424),
#  ImageClassificationOutputElement(label='fear', score=0.13038107752799988),
#  ImageClassificationOutputElement(label='happy', score=0.09617579728364944),
#  ImageClassificationOutputElement(label='neutral', score=0.07203307002782822),
#  ImageClassificationOutputElement(label='surprise', score=0.057427793741226196),
#  ImageClassificationOutputElement(label='happy', score=0.38719409704208374),
#  ImageClassificationOutputElement(label='neutral', score=0.3525014817714691),
#  ImageClassificationOutputElement(label='sad', score=0.11795074492692947),
#  ImageClassificationOutputElement(label='surprise', score=0.07275313884019852),
#  ImageClassificationOutputElement(label='fear', score=0.038694992661476135),
#  ImageClassificationOutputElement(label='fear', score=0.4923709034919739),
#  ImageClassificationOutputElement(label='neutral', score=0.1689019799232483),
#  ImageClassificationOutputElement(label='sad', score=0.13062530755996704),
#  ImageClassificationOutputElement(label='angry', score=0.0893605500459671),
#  ImageClassificationOutputElement(label='surprise', score=0.07855266332626343),
#  ImageClassificationOutputElement(label='sad', score=0.3802100121974945),
#  ImageClassificationOutputElement(label='neutral', score=0.31808364391326904),
#  ImageClassificationOutputElement(label='happy', score=0.18527264893054962),
#  ImageClassificationOutputElement(label='angry', score=0.08532963693141937),
#  ImageClassificationOutputElement(label='fear', score=0.015926171094179153),
#  ImageClassificationOutputElement(label='happy', score=0.5103437900543213),
#  ImageClassificationOutputElement(label='sad', score=0.27552300691604614),
#  ImageClassificationOutputElement(label='neutral', score=0.1723652184009552),
#  ImageClassificationOutputElement(label='fear', score=0.01570953242480755),
#  ImageClassificationOutputElement(label='surprise', score=0.011386184021830559),
#  ImageClassificationOutputElement(label='happy', score=0.9641185998916626),
#  ImageClassificationOutputElement(label='neutral', score=0.011999077163636684),
#  ImageClassificationOutputElement(label='surprise', score=0.010459112003445625),
#  ImageClassificationOutputElement(label='sad', score=0.006559820845723152),
#  ImageClassificationOutputElement(label='fear', score=0.0024279081262648106),
#  ImageClassificationOutputElement(label='neutral', score=0.425039142370224),
#  ImageClassificationOutputElement(label='sad', score=0.27146095037460327),
#  ImageClassificationOutputElement(label='happy', score=0.20640669763088226),
#  ImageClassificationOutputElement(label='surprise', score=0.03434813395142555),
#  ImageClassificationOutputElement(label='fear', score=0.032246366143226624),
#  ImageClassificationOutputElement(label='neutral', score=0.40578824281692505),
#  ImageClassificationOutputElement(label='angry', score=0.33026567101478577),
#  ImageClassificationOutputElement(label='sad', score=0.09725967794656754),
#  ImageClassificationOutputElement(label='fear', score=0.0595969520509243),
#  ImageClassificationOutputElement(label='surprise', score=0.04757823422551155),
#  ImageClassificationOutputElement(label='neutral', score=0.4442519545555115),
#  ImageClassificationOutputElement(label='angry', score=0.18670377135276794),
#  ImageClassificationOutputElement(label='happy', score=0.15150338411331177),
#  ImageClassificationOutputElement(label='sad', score=0.0851743221282959),
#  ImageClassificationOutputElement(label='surprise', score=0.0546623058617115),
#  ImageClassificationOutputElement(label='neutral', score=0.69631028175354),
#  ImageClassificationOutputElement(label='sad', score=0.10074193775653839),
#  ImageClassificationOutputElement(label='happy', score=0.07182386517524719),
#  ImageClassificationOutputElement(label='angry', score=0.06993609666824341),
#  ImageClassificationOutputElement(label='fear', score=0.021943287923932076),
#  ImageClassificationOutputElement(label='sad', score=0.7228394150733948),
#  ImageClassificationOutputElement(label='fear', score=0.10755999386310577),
#  ImageClassificationOutputElement(label='neutral', score=0.07236412167549133),
#  ImageClassificationOutputElement(label='angry', score=0.04842279851436615),
#  ImageClassificationOutputElement(label='happy', score=0.03213679790496826),
#  ImageClassificationOutputElement(label='sad', score=0.5609543323516846),
#  ImageClassificationOutputElement(label='fear', score=0.20958691835403442),
#  ImageClassificationOutputElement(label='neutral', score=0.1170339286327362),
#  ImageClassificationOutputElement(label='angry', score=0.06051064282655716),
#  ImageClassificationOutputElement(label='happy', score=0.02511744759976864),
#  ImageClassificationOutputElement(label='sad', score=0.22236604988574982),
#  ImageClassificationOutputElement(label='angry', score=0.21919088065624237),
#  ImageClassificationOutputElement(label='happy', score=0.1958661526441574),
#  ImageClassificationOutputElement(label='neutral', score=0.18375688791275024),
#  ImageClassificationOutputElement(label='fear', score=0.09461774677038193),
#  ImageClassificationOutputElement(label='angry', score=0.29947152733802795),
#  ImageClassificationOutputElement(label='sad', score=0.19574402272701263),
#  ImageClassificationOutputElement(label='neutral', score=0.19407309591770172),
#  ImageClassificationOutputElement(label='fear', score=0.1364331841468811),
#  ImageClassificationOutputElement(label='happy', score=0.09504081308841705),
#  ImageClassificationOutputElement(label='neutral', score=0.3895471692085266),
#  ImageClassificationOutputElement(label='happy', score=0.38241681456565857),
#  ImageClassificationOutputElement(label='angry', score=0.10902146995067596),
#  ImageClassificationOutputElement(label='sad', score=0.072560153901577),
#  ImageClassificationOutputElement(label='fear', score=0.016995050013065338),
#  ImageClassificationOutputElement(label='happy', score=0.584335207939148),
#  ImageClassificationOutputElement(label='neutral', score=0.31454432010650635),
#  ImageClassificationOutputElement(label='angry', score=0.03302526846528053),
#  ImageClassificationOutputElement(label='sad', score=0.028222983703017235),
#  ImageClassificationOutputElement(label='surprise', score=0.016930753365159035),
#  ImageClassificationOutputElement(label='fear', score=0.2712343633174896),
#  ImageClassificationOutputElement(label='neutral', score=0.2424837350845337),
#  ImageClassificationOutputElement(label='sad', score=0.21599933505058289),
#  ImageClassificationOutputElement(label='surprise', score=0.11327110975980759),
#  ImageClassificationOutputElement(label='angry', score=0.08435458689928055),
#  ImageClassificationOutputElement(label='neutral', score=0.5524396300315857),
#  ImageClassificationOutputElement(label='sad', score=0.1572573035955429),
#  ImageClassificationOutputElement(label='happy', score=0.15396447479724884),
#  ImageClassificationOutputElement(label='angry', score=0.060895003378391266),
#  ImageClassificationOutputElement(label='fear', score=0.038674868643283844),
#  ImageClassificationOutputElement(label='neutral', score=0.5026904344558716),
#  ImageClassificationOutputElement(label='sad', score=0.201729878783226),
#  ImageClassificationOutputElement(label='happy', score=0.11317608505487442),
#  ImageClassificationOutputElement(label='fear', score=0.08704057335853577),
#  ImageClassificationOutputElement(label='angry', score=0.05178777873516083),
#  ImageClassificationOutputElement(label='fear', score=0.4118354022502899),
#  ImageClassificationOutputElement(label='neutral', score=0.26226112246513367),
#  ImageClassificationOutputElement(label='sad', score=0.11427926272153854),
#  ImageClassificationOutputElement(label='happy', score=0.108802929520607),
#  ImageClassificationOutputElement(label='angry', score=0.05228861793875694),
#  ImageClassificationOutputElement(label='happy', score=0.8130850791931152),
#  ImageClassificationOutputElement(label='neutral', score=0.07248632609844208),
#  ImageClassificationOutputElement(label='sad', score=0.043210018426179886),
#  ImageClassificationOutputElement(label='fear', score=0.025763006880879402),
#  ImageClassificationOutputElement(label='angry', score=0.022441666573286057),
#  ImageClassificationOutputElement(label='neutral', score=0.4506106376647949),
#  ImageClassificationOutputElement(label='sad', score=0.3418140411376953),
#  ImageClassificationOutputElement(label='angry', score=0.08552903681993484),
#  ImageClassificationOutputElement(label='fear', score=0.05309503525495529),
#  ImageClassificationOutputElement(label='happy', score=0.05003760755062103),
#  ImageClassificationOutputElement(label='angry', score=0.27557486295700073),
#  ImageClassificationOutputElement(label='sad', score=0.257291704416275),
#  ImageClassificationOutputElement(label='fear', score=0.21448570489883423),
#  ImageClassificationOutputElement(label='neutral', score=0.14629048109054565),
#  ImageClassificationOutputElement(label='happy', score=0.07252638041973114),
#  ImageClassificationOutputElement(label='surprise', score=0.6995575428009033),
#  ImageClassificationOutputElement(label='fear', score=0.1673852801322937),
#  ImageClassificationOutputElement(label='happy', score=0.06013305112719536),
#  ImageClassificationOutputElement(label='angry', score=0.034303780645132065),
#  ImageClassificationOutputElement(label='neutral', score=0.020071791484951973)]

# %% [markdown]
# ### Обращение к модели google/gemma-3-27b-it

# %%
client = InferenceClient(
    api_key=os.environ["HF_TOKEN"],
)
for i in range (0,39):
    completion = client.chat.completions.create(
        model="google/gemma-3-27b-it:scaleway",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": "есть список эмоций: Angry Disgust Fear Happy Sad Surprise Neutral. Проанализируй фотографию и выведи вероятность принадлежности фото определенной эмоции. Ответ выведи в таком формате: 'Название эмоции': 'Вероятность дробным числом (например, 0.22, не 22%)'. Напиши только 5 самых возможных эмоций. Больше ничего не добавляй"
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/jpeg;base64,{base64_images[i]}"
                        }
                    }
                ]
            }
        ],
    )
    output_gemma.append(completion.choices[0].message.content)
    time.sleep(10)
output_gemma
# Out:
# ["'Neutral': '0.65'\n'Sad': '0.15'\n'Fear': '0.10'\n'Surprise': '0.05'\n'Disgust': '0.05'",
#  "'Surprise': '0.85'\n'Fear': '0.10'\n'Neutral': '0.03'\n'Disgust': '0.01'\n'Sad': '0.01'",
#  "'Fear': '0.78'\n'Surprise': '0.15'\n'Sad': '0.03'\n'Neutral': '0.02'\n'Disgust': '0.01'",
#  "'Neutral': '0.75'\n'Sad': '0.12'\n'Fear': '0.05'\n'Disgust': '0.04'\n'Angry': '0.04'",
#  "'Surprise': 0.65\n'Fear': 0.20\n'Neutral': 0.10\n'Sad': 0.03\n'Disgust': 0.02",
#  "'Happy': '0.95'\n'Neutral': '0.03'\n'Surprise': '0.01'\n'Sad': '0.005'\n'Angry': '0.005'",
#  "'Neutral': '0.78'\n'Sad': '0.11'\n'Fear': '0.05'\n'Disgust': '0.03'\n'Surprise': '0.03'",
#  "'Neutral': '0.85'\n'Sad': '0.08'\n'Fear': '0.03'\n'Disgust': '0.02'\n'Surprise': '0.01'",
#  "'Sad': '0.65'\n'Neutral': '0.20'\n'Angry': '0.07'\n'Disgust': '0.05'\n'Fear': '0.03'",
#  "'Neutral': 0.75\n'Sad': 0.10\n'Fear': 0.05\n'Disgust': 0.04\n'Angry': 0.03",
#  "'Neutral': 0.75\n'Sad': 0.12\n'Disgust': 0.05\n'Fear': 0.04\n'Surprise': 0.04",
#  "'Neutral': '0.85'\n'Sad': '0.10'\n'Fear': '0.03'\n'Disgust': '0.01'\n'Surprise': '0.01'",
#  "'Neutral': '0.65'\n'Sad': '0.15'\n'Surprise': '0.10'\n'Disgust': '0.05'\n'Fear': '0.05'",
#  "'Surprise': '0.75'\n'Fear': '0.15'\n'Neutral': '0.04'\n'Disgust': '0.03'\n'Sad': '0.03'",
#  "'Angry': '0.65'\n'Sad': '0.15'\n'Disgust': '0.10'\n'Neutral': '0.07'\n'Fear': '0.03'",
#  "'Neutral': '0.65'\n'Sad': '0.15'\n'Disgust': '0.10'\n'Fear': '0.05'\n'Surprise': '0.05'",
#  "'Surprise': 0.65\n'Fear': 0.15\n'Neutral': 0.10\n'Sad': 0.05\n'Angry': 0.05",
#  "'Neutral': '0.85'\n'Sad': '0.08'\n'Fear': '0.03'\n'Disgust': '0.02'\n'Surprise': '0.02'",
#  "'Neutral': '0.85'\n'Happy': '0.08'\n'Sad': '0.03'\n'Surprise': '0.02'\n'Fear': '0.01'",
#  "'Neutral': '0.65'\n'Sad': '0.15'\n'Disgust': '0.10'\n'Angry': '0.05'\n'Fear': '0.05'",
#  "'Neutral': '0.65'\n'Happy': '0.20'\n'Sad': '0.05'\n'Surprise': '0.04'\n'Disgust': '0.03'",
#  "'Neutral': '0.78'\n'Sad': '0.11'\n'Disgust': '0.05'\n'Fear': '0.03'\n'Surprise': '0.02'",
#  "'Angry': '0.45'\n'Disgust': '0.30'\n'Sad': '0.10'\n'Fear': '0.08'\n'Neutral': '0.07'",
#  "'Surprise': '0.85'\n'Fear': '0.10'\n'Happy': '0.03'\n'Neutral': '0.01'\n'Disgust': '0.01'",
#  "'Surprise': '0.78'\n'Fear': '0.15'\n'Angry': '0.03'\n'Disgust': '0.02'\n'Sad': '0.01'",
#  "'Neutral': '0.75'\n'Sad': '0.12'\n'Fear': '0.05'\n'Surprise': '0.04'\n'Disgust': '0.04'",
#  "'Neutral': 0.75\n'Sad': 0.10\n'Fear': 0.05\n'Surprise': 0.04\n'Disgust': 0.03",
#  "'Neutral': '0.68'\n'Sad': '0.15'\n'Disgust': '0.07'\n'Angry': '0.06'\n'Fear': '0.04'",
#  "'Surprise': '0.68'\n'Fear': '0.15'\n'Neutral': '0.10'\n'Sad': '0.04'\n'Disgust': '0.03'",
#  "'Surprise': '0.75'\n'Fear': '0.15'\n'Neutral': '0.05'\n'Sad': '0.03'\n'Disgust': '0.02'",
#  "'Surprise': '0.45'\n'Fear': '0.25'\n'Sad': '0.15'\n'Neutral': '0.10'\n'Disgust': '0.05'",
#  "'Surprise': '0.75'\n'Fear': '0.15'\n'Neutral': '0.05'\n'Sad': '0.03'\n'Disgust': '0.02'",
#  "'Neutral': '0.65'\n'Sad': '0.20'\n'Angry': '0.08'\n'Disgust': '0.04'\n'Fear': '0.03'",
#  "'Surprise': '0.75'\n'Fear': '0.15'\n'Neutral': '0.05'\n'Sad': '0.03'\n'Disgust': '0.02'",
#  "'Neutral': '0.65'\n'Sad': '0.20'\n'Disgust': '0.07'\n'Fear': '0.05'\n'Surprise': '0.03'",
#  "'Happy': '0.88'\n'Neutral': '0.08'\n'Surprise': '0.02'\n'Sad': '0.01'\n'Disgust': '0.01'",
#  "'Sad': '0.85'\n'Neutral': '0.55'\n'Disgust': '0.32'\n'Angry': '0.18'\n'Fear': '0.12'",
#  "'Neutral': '0.75'\n'Happy': '0.15'\n'Sad': '0.04'\n'Surprise': '0.03'\n'Disgust': '0.02'",
#  "'Angry': '0.75'\n'Sad': '0.15'\n'Disgust': '0.05'\n'Neutral': '0.03'\n'Fear': '0.02'"]

# %% [markdown]
# ### Обращение к модели Qwen/Qwen2.5-VL-7B-Instruct

# %%
client = InferenceClient(
    api_key=os.environ["HF_TOKEN"],
)
for i in range(0,39):
    completion = client.chat.completions.create(
        model="Qwen/Qwen2.5-VL-7B-Instruct:hyperbolic",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": "есть список эмоций: Angry Disgust Fear Happy Sad Surprise Neutral. Проанализируй фотографию и выведи вероятность принадлежности фото определенной эмоции. Ответ выведи в таком формате: 'Название эмоции': 'Вероятность дробным числом (например, 0.22, не 22%)'. Напиши только 5 самых возможных эмоций. Больше ничего не добавляй"
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/jpeg;base64,{base64_images[i]}"
                        }
                    }
                ]
            }
        ],
    )
    output_qwen.append(completion.choices[0].message.content)
    time.sleep(10)
output_qwen
# Out:
# ["'Angry': '0.45'\n'Neutral': '0.32'\n'Sad': '0.18'\n'Happy': '0.05'\n'Neutral': '0.05'",
#  'Surprise: 0.85\nFear: 0.12\nAngry: 0.05\nDisgust: 0.02\nHappy: 0.01',
#  'Neutral: 0.65\nHappy: 0.15\nSad: 0.10\nSurprise: 0.05\nFear: 0.05',
#  'Neutral: 0.85\nHappy: 0.08\nSad: 0.06\nAngry: 0.03\nDisgust: 0.02',
#  'Surprise: 0.65\nHappy: 0.20\nSad: 0.10\nNeutral: 0.05\nFear: 0.05',
#  'Happy: 0.85\nNeutral: 0.10\nSad: 0.05\nSurprise: 0.03\nFear: 0.02',
#  'Neutral: 0.95\nSad: 0.03\nDisgust: 0.02\nHappy: 0.01\nAngry: 0.01',
#  'Angry: 0.95\nDisgust: 0.78\nNeutral: 0.15\nFear: 0.05\nSad: 0.02',
#  "'Angry': '0.85'\n'Disgust': '0.15'\n'Fear': '0.05'\n'Happy': '0.02'\n'Sad': '0.03'",
#  "'Neutral': '0.75'",
#  "'Neutral': '0.30'  \n'Happy': '0.25'  \n'Sad': '0.20'  \n'Angry': '0.15'  \n'Neutral': '0.10'",
#  'Neutral: 0.85\nAngry: 0.08\nDisgust: 0.05\nSad: 0.02\nHappy: 0.01',
#  "'Fear': '0.45'\n'Angry': '0.30'\n'Neutral': '0.20'\n'Sad': '0.05'\n'Happy': '0.05'",
#  "'Neutral': '0.15'\n'Happy': '0.20'\n'Surprise': '0.25'\n'Angry': '0.20'\n'Fear': '0.20'",
#  'Angry: 0.72\nDisgust: 0.20\nFear: 0.05\nNeutral: 0.03\nHappy: 0.02',
#  "'Neutral': '0.40'\n'Angry': '0.30'\n'Sad': '0.15'\n'Happy': '0.10'\n'Disgust': '0.05'",
#  "'Happy': '0.15'\n'Sad': '0.20'\n'Neutral': '0.30'\n'Angry': '0.20'\n'Fear': '0.15'",
#  'Neutral: 0.95\nHappy: 0.03\nSad: 0.02\nDisgust: 0.01\nAngry: 0.01',
#  'Angry: 0.85\nNeutral: 0.10\nDisgust: 0.05\nSad: 0.05\nSurprise: 0.05',
#  "'Angry': '0.85'\n'Disgust': '0.10'\n'Fear': '0.05'\n'Sad': '0.03'\n'Neutral': '0.02'",
#  'Happy: 0.8\nNeutral: 0.15\nSad: 0.05\nNeutral: 0.05\nNeutral: 0.05',
#  'Neutral: 0.4  \nHappy: 0.15  \nSad: 0.2  \nSurprise: 0.1  \nDisgust: 0.15',
#  'Angry: 0.85\nDisgust: 0.10\nSad: 0.05\nNeutral: 0.03\nSurprise: 0.02',
#  "'Happy': '0.12'\n'Neutral': '0.45'\n'Surprise': '0.43'\n'Angry': '0.08'\n'Fear': '0.02'",
#  'Angry: 0.85\nHappy: 0.15\nNeutral: 0.05\nDisgust: 0.05\nSurprise: 0.05',
#  'Neutral: 0.95\nHappy: 0.03\nSurprise: 0.02\nSad: 0.01\nFear: 0.01',
#  'Neutral: 0.55\nHappy: 0.30\nSad: 0.15\nSurprise: 0.05\nFear: 0.05',
#  'Angry: 0.23\nDisgust: 0.45\nFear: 0.12\nNeutral: 0.10\nSurprise: 0.05',
#  "'Happy': '0.35'\n'Sad': '0.28'\n'Neutral': '0.19'\n'Angry': '0.12'\n'Disgust': '0.14'",
#  'Surprise: 0.85\nNeutral: 0.10\nHappy: 0.05\nSad: 0.03\nFear: 0.02',
#  'Surprise: 0.85\nAngry: 0.10\nNeutral: 0.05\nDisgust: 0.03\nSad: 0.02',
#  'Surprise: 0.85\nFear: 0.10\nHappy: 0.05\nSad: 0.02\nNeutral: 0.03',
#  'Neutral: 0.45\nHappy: 0.30\nSad: 0.15\nDisgust: 0.05\nSurprise: 0.05',
#  "'Happy': '0.30'\n'Surprise': '0.45'\n'Neutral': '0.15'\n'Angry': '0.05'\n'Fear': '0.05'",
#  'Sad: 0.75\nAngry: 0.20\nNeutral: 0.05\nDisgust: 0.03\nFear: 0.02',
#  "'Happy': '0.85'\n'Neutral': '0.12'\n'Sad': '0.05'\n'Neutral': '0.03'\n'Neutral': '0.01'",
#  "'Angry': '0.98'\n'Sad': '0.05'\n'Neutral': '0.02'\n'Disgust': '0.01'\n'Fear': '0.01'",
#  "'Happy': '0.65'\n'Neutral': '0.25'\n'Sad': '0.10'\n'Neutral': '0.05'",
#  'Angry: 0.95\nDisgust: 0.05\nFear: 0.01\nHappy: 0.01\nSad: 0.01']

# %%
data = []
for i, result in enumerate(output):
    data.append({
        'labelF': result['label'],
        'scoreF': result['score']
    })
df = pd.DataFrame(data)
df
# Out:
#        labelF    scoreF
# 0     neutral  0.746008
# 1         sad  0.103266
# 2        fear  0.058445
# 3       happy  0.043354
# 4       angry  0.032512
# ..        ...       ...
# 190  surprise  0.699558
# 191      fear  0.167385
# 192     happy  0.060133
# 193     angry  0.034304
# 194   neutral  0.020072
#
# [195 rows x 2 columns]

# %%
filtered_gemma = []
allowed_words = ["Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"]
pattern = r'\d+[,.]?\d*|%|' + '|'.join(re.escape(word) for word in allowed_words)
for string in output_gemma:
    matches = re.findall(pattern, string)
    filtered_string = ' '.join(matches)
    if filtered_string.startswith('5 '):
        filtered_string = filtered_string[2:]
    filtered_gemma.append(filtered_string)
filtered_gemma
# Out:
# ['Neutral 0.65 Sad 0.15 Fear 0.10 Surprise 0.05 Disgust 0.05',
#  'Surprise 0.85 Fear 0.10 Neutral 0.03 Disgust 0.01 Sad 0.01',
#  'Fear 0.78 Surprise 0.15 Sad 0.03 Neutral 0.02 Disgust 0.01',
#  'Neutral 0.75 Sad 0.12 Fear 0.05 Disgust 0.04 Angry 0.04',
#  'Surprise 0.65 Fear 0.20 Neutral 0.10 Sad 0.03 Disgust 0.02',
#  'Happy 0.95 Neutral 0.03 Surprise 0.01 Sad 0.005 Angry 0.005',
#  'Neutral 0.78 Sad 0.11 Fear 0.05 Disgust 0.03 Surprise 0.03',
#  'Neutral 0.85 Sad 0.08 Fear 0.03 Disgust 0.02 Surprise 0.01',
#  'Sad 0.65 Neutral 0.20 Angry 0.07 Disgust 0.05 Fear 0.03',
#  'Neutral 0.75 Sad 0.10 Fear 0.05 Disgust 0.04 Angry 0.03',
#  'Neutral 0.75 Sad 0.12 Disgust 0.05 Fear 0.04 Surprise 0.04',
#  'Neutral 0.85 Sad 0.10 Fear 0.03 Disgust 0.01 Surprise 0.01',
#  'Neutral 0.65 Sad 0.15 Surprise 0.10 Disgust 0.05 Fear 0.05',
#  'Surprise 0.75 Fear 0.15 Neutral 0.04 Disgust 0.03 Sad 0.03',
#  'Angry 0.65 Sad 0.15 Disgust 0.10 Neutral 0.07 Fear 0.03',
#  'Neutral 0.65 Sad 0.15 Disgust 0.10 Fear 0.05 Surprise 0.05',
#  'Surprise 0.65 Fear 0.15 Neutral 0.10 Sad 0.05 Angry 0.05',
#  'Neutral 0.85 Sad 0.08 Fear 0.03 Disgust 0.02 Surprise 0.02',
#  'Neutral 0.85 Happy 0.08 Sad 0.03 Surprise 0.02 Fear 0.01',
#  'Neutral 0.65 Sad 0.15 Disgust 0.10 Angry 0.05 Fear 0.05',
#  'Neutral 0.65 Happy 0.20 Sad 0.05 Surprise 0.04 Disgust 0.03',
#  'Neutral 0.78 Sad 0.11 Disgust 0.05 Fear 0.03 Surprise 0.02',
#  'Angry 0.45 Disgust 0.30 Sad 0.10 Fear 0.08 Neutral 0.07',
#  'Surprise 0.85 Fear 0.10 Happy 0.03 Neutral 0.01 Disgust 0.01',
#  'Surprise 0.78 Fear 0.15 Angry 0.03 Disgust 0.02 Sad 0.01',
#  'Neutral 0.75 Sad 0.12 Fear 0.05 Surprise 0.04 Disgust 0.04',
#  'Neutral 0.75 Sad 0.10 Fear 0.05 Surprise 0.04 Disgust 0.03',
#  'Neutral 0.68 Sad 0.15 Disgust 0.07 Angry 0.06 Fear 0.04',
#  'Surprise 0.68 Fear 0.15 Neutral 0.10 Sad 0.04 Disgust 0.03',
#  'Surprise 0.75 Fear 0.15 Neutral 0.05 Sad 0.03 Disgust 0.02',
#  'Surprise 0.45 Fear 0.25 Sad 0.15 Neutral 0.10 Disgust 0.05',
#  'Surprise 0.75 Fear 0.15 Neutral 0.05 Sad 0.03 Disgust 0.02',
#  'Neutral 0.65 Sad 0.20 Angry 0.08 Disgust 0.04 Fear 0.03',
#  'Surprise 0.75 Fear 0.15 Neutral 0.05 Sad 0.03 Disgust 0.02',
#  'Neutral 0.65 Sad 0.20 Disgust 0.07 Fear 0.05 Surprise 0.03',
#  'Happy 0.88 Neutral 0.08 Surprise 0.02 Sad 0.01 Disgust 0.01',
#  'Sad 0.85 Neutral 0.55 Disgust 0.32 Angry 0.18 Fear 0.12',
#  'Neutral 0.75 Happy 0.15 Sad 0.04 Surprise 0.03 Disgust 0.02',
#  'Angry 0.75 Sad 0.15 Disgust 0.05 Neutral 0.03 Fear 0.02']

# %%
filtered_qwen = []
for string in output_qwen:
    text = re.sub(r'\b\d+\.\s+', '', string)
    matches = re.findall(pattern, text)
    filtered_string_qwen = ' '.join(matches)
    filtered_string_qwen = ' '.join(dict.fromkeys(filtered_string_qwen.split()))
    filtered_qwen.append(filtered_string_qwen)
filtered_qwen
# Out:
# ['Angry 0.45 Neutral 0.32 Sad 0.18 Happy 0.05',
#  'Surprise 0.85 Fear 0.12 Angry 0.05 Disgust 0.02 Happy 0.01',
#  'Neutral 0.65 Happy 0.15 Sad 0.10 Surprise 0.05 Fear',
#  'Neutral 0.85 Happy 0.08 Sad 0.06 Angry 0.03 Disgust 0.02',
#  'Surprise 0.65 Happy 0.20 Sad 0.10 Neutral 0.05 Fear',
#  'Happy 0.85 Neutral 0.10 Sad 0.05 Surprise 0.03 Fear 0.02',
#  'Neutral 0.95 Sad 0.03 Disgust 0.02 Happy 0.01 Angry',
#  'Angry 0.95 Disgust 0.78 Neutral 0.15 Fear 0.05 Sad 0.02',
#  'Angry 0.85 Disgust 0.15 Fear 0.05 Happy 0.02 Sad 0.03',
#  'Neutral 0.75',
#  'Neutral 0.30 Happy 0.25 Sad 0.20 Angry 0.15 0.10',
#  'Neutral 0.85 Angry 0.08 Disgust 0.05 Sad 0.02 Happy 0.01',
#  'Fear 0.45 Angry 0.30 Neutral 0.20 Sad 0.05 Happy',
#  'Neutral 0.15 Happy 0.20 Surprise 0.25 Angry Fear',
#  'Angry 0.72 Disgust 0.20 Fear 0.05 Neutral 0.03 Happy 0.02',
#  'Neutral 0.40 Angry 0.30 Sad 0.15 Happy 0.10 Disgust 0.05',
#  'Happy 0.15 Sad 0.20 Neutral 0.30 Angry Fear',
#  'Neutral 0.95 Happy 0.03 Sad 0.02 Disgust 0.01 Angry',
#  'Angry 0.85 Neutral 0.10 Disgust 0.05 Sad Surprise',
#  'Angry 0.85 Disgust 0.10 Fear 0.05 Sad 0.03 Neutral 0.02',
#  'Happy 0.8 Neutral 0.15 Sad 0.05',
#  'Neutral 0.4 Happy 0.15 Sad 0.2 Surprise 0.1 Disgust',
#  'Angry 0.85 Disgust 0.10 Sad 0.05 Neutral 0.03 Surprise 0.02',
#  'Happy 0.12 Neutral 0.45 Surprise 0.43 Angry 0.08 Fear 0.02',
#  'Angry 0.85 Happy 0.15 Neutral 0.05 Disgust Surprise',
#  'Neutral 0.95 Happy 0.03 Surprise 0.02 Sad 0.01 Fear',
#  'Neutral 0.55 Happy 0.30 Sad 0.15 Surprise 0.05 Fear',
#  'Angry 0.23 Disgust 0.45 Fear 0.12 Neutral 0.10 Surprise 0.05',
#  'Happy 0.35 Sad 0.28 Neutral 0.19 Angry 0.12 Disgust 0.14',
#  'Surprise 0.85 Neutral 0.10 Happy 0.05 Sad 0.03 Fear 0.02',
#  'Surprise 0.85 Angry 0.10 Neutral 0.05 Disgust 0.03 Sad 0.02',
#  'Surprise 0.85 Fear 0.10 Happy 0.05 Sad 0.02 Neutral 0.03',
#  'Neutral 0.45 Happy 0.30 Sad 0.15 Disgust 0.05 Surprise',
#  'Happy 0.30 Surprise 0.45 Neutral 0.15 Angry 0.05 Fear',
#  'Sad 0.75 Angry 0.20 Neutral 0.05 Disgust 0.03 Fear 0.02',
#  'Happy 0.85 Neutral 0.12 Sad 0.05 0.03 0.01',
#  'Angry 0.98 Sad 0.05 Neutral 0.02 Disgust 0.01 Fear',
#  'Happy 0.65 Neutral 0.25 Sad 0.10 0.05',
#  'Angry 0.95 Disgust 0.05 Fear 0.01 Happy Sad']

# %%
pattern = r'([A-Za-z]+)\s+(\d+\.\d+)'
all_data = []
for string in filtered_gemma:
    matches = re.findall(pattern, string)
    for label, score in matches:
        all_data.append({
            'labelG': label,
            'scoreG': float(score)
        })
df_gemma = pd.DataFrame(all_data)
df_gemma
# Out:
#        labelG  scoreG
# 0     Neutral    0.65
# 1         Sad    0.15
# 2        Fear    0.10
# 3    Surprise    0.05
# 4     Disgust    0.05
# ..        ...     ...
# 190     Angry    0.75
# 191       Sad    0.15
# 192   Disgust    0.05
# 193   Neutral    0.03
# 194      Fear    0.02
#
# [195 rows x 2 columns]

# %%
all_data = []
for i, string in enumerate(filtered_qwen):
    matches = re.findall(pattern, string)
    for label, score in matches:
        all_data.append({
            'row_index': i,
            'labelQ': label,
            'scoreQ': float(score)
        })
df_qwen = pd.DataFrame(all_data)
df_qwen
# Out:
#      row_index    labelQ  scoreQ
# 0            0     Angry    0.45
# 1            0   Neutral    0.32
# 2            0       Sad    0.18
# 3            0     Happy    0.05
# 4            1  Surprise    0.85
# ..         ...       ...     ...
# 157         37   Neutral    0.25
# 158         37       Sad    0.10
# 159         38     Angry    0.95
# 160         38   Disgust    0.05
# 161         38      Fear    0.01
#
# [162 rows x 3 columns]

# %%
all_files = os.listdir(folder_path)
photo_names = [f for f in all_files]
photo_names = natsorted(photo_names)
repeated_names = np.repeat(photo_names, 5)
df['photo_name'] = repeated_names
df['labelF'] = df['labelF'].str.capitalize()
df
# Out:
#        labelF    scoreF   photo_name emotion
# 0     Neutral  0.746008   0Angry.jpg   Angry
# 1         Sad  0.103266   0Angry.jpg   Angry
# 2        Fear  0.058445   0Angry.jpg   Angry
# 3       Happy  0.043354   0Angry.jpg   Angry
# 4       Angry  0.032512   0Angry.jpg   Angry
# ..        ...       ...          ...     ...
# 190  Surprise  0.699558  18Angry.jpg   Angry
# 191      Fear  0.167385  18Angry.jpg   Angry
# 192     Happy  0.060133  18Angry.jpg   Angry
# 193     Angry  0.034304  18Angry.jpg   Angry
# 194   Neutral  0.020072  18Angry.jpg   Angry
#
# [195 rows x 4 columns]

# %%
df_gemma['photo_name'] = repeated_names
df_gemma
# Out:
#        labelG  scoreG   photo_name
# 0     Neutral    0.65   0Angry.jpg
# 1         Sad    0.15   0Angry.jpg
# 2        Fear    0.10   0Angry.jpg
# 3    Surprise    0.05   0Angry.jpg
# 4     Disgust    0.05   0Angry.jpg
# ..        ...     ...          ...
# 190     Angry    0.75  18Angry.jpg
# 191       Sad    0.15  18Angry.jpg
# 192   Disgust    0.05  18Angry.jpg
# 193   Neutral    0.03  18Angry.jpg
# 194      Fear    0.02  18Angry.jpg
#
# [195 rows x 3 columns]

# %%
df_qwen['photo_name'] = df_qwen['row_index'].apply(lambda x: photo_names[x])
df_qwen_f = df_qwen.drop('row_index',axis=1)
df_qwen_f
# Out:
#        labelQ  scoreQ   photo_name
# 0       Angry    0.45   0Angry.jpg
# 1     Neutral    0.32   0Angry.jpg
# 2         Sad    0.18   0Angry.jpg
# 3       Happy    0.05   0Angry.jpg
# 4    Surprise    0.85    0Fear.jpg
# ..        ...     ...          ...
# 157   Neutral    0.25  17Happy.jpg
# 158       Sad    0.10  17Happy.jpg
# 159     Angry    0.95  18Angry.jpg
# 160   Disgust    0.05  18Angry.jpg
# 161      Fear    0.01  18Angry.jpg
#
# [162 rows x 3 columns]

# %%
#df.to_csv('facial_data.csv')
#df_gemma.to_csv('gemma_data.csv')
#df_qwen_f.to_csv('qwen_data.csv')
df = pd.read_csv('facial_data.csv')
df_gemma = pd.read_csv('gemma_data.csv')
df_qwen_f = pd.read_csv('qwen_data.csv')

# %%
res_df = df.loc[df.groupby('photo_name')['scoreF'].idxmax()]
res_df_gemma = df_gemma.loc[df_gemma.groupby('photo_name')['scoreG'].idxmax()]
res_df_qwen = df_qwen_f.loc[df_qwen_f.groupby('photo_name')['scoreQ'].idxmax()]
res_df_qwen
# Out:
#        labelQ  scoreQ      photo_name
# 0       Angry    0.45      0Angry.jpg
# 4    Surprise    0.85       0Fear.jpg
# 9     Neutral    0.65    0Neutral.jpg
# 100     Angry    0.85  10Surprise.jpg
# 103   Neutral    0.95   11Neutral.jpg
# 107   Neutral    0.55       11Sad.jpg
# 112   Disgust    0.45   12Disgust.jpg
# 116     Happy    0.35      12Fear.jpg
# 121  Surprise    0.85  12Surprise.jpg
# 126  Surprise    0.85      13Fear.jpg
# 131  Surprise    0.85  13Surprise.jpg
# 136   Neutral    0.45     14Angry.jpg
# 141  Surprise    0.45      15Fear.jpg
# 144       Sad    0.75       15Sad.jpg
# 149     Happy    0.85     16Happy.jpg
# 152     Angry    0.98   17Disgust.jpg
# 156     Happy    0.65     17Happy.jpg
# 159     Angry    0.95     18Angry.jpg
# 13    Neutral    0.85      1Angry.jpg
# 18   Surprise    0.65       1Fear.jpg
# 22      Happy    0.85      1Happy.jpg
# 27    Neutral    0.95   1Surprise.jpg
# 31      Angry    0.95      3Angry.jpg
# 36      Angry    0.85    3Disgust.jpg
# 41    Neutral    0.75        3Sad.jpg
# 42    Neutral    0.30    4Disgust.jpg
# 46    Neutral    0.85    4Neutral.jpg
# 51       Fear    0.45    5Disgust.jpg
# 57   Surprise    0.25       5Fear.jpg
# 58      Angry    0.72      6Angry.jpg
# 63    Neutral    0.40    6Disgust.jpg
# 70    Neutral    0.30       7Fear.jpg
# 71    Neutral    0.95    7Neutral.jpg
# 75      Angry    0.85        7Sad.jpg
# 78      Angry    0.85    8Disgust.jpg
# 83      Happy    0.80      8Happy.jpg
# 86    Neutral    0.40        8Sad.jpg
# 90      Angry    0.85      9Angry.jpg
# 96    Neutral    0.45   9Surprise.jpg

# %%
res_df['emotion'] = res_df['photo_name'].str.extract(r'(\D+)\.')[0]
res_df['labelF'] = res_df['labelF'].str.capitalize()
res_df_gemma['emotion'] = res_df_gemma['photo_name'].str.extract(r'(\D+)\.')[0]
res_df_qwen['emotion'] = res_df_qwen['photo_name'].str.extract(r'(\D+)\.')[0]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(res_df['emotion'],res_df['labelF'])
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels = sorted(list(res_df['emotion'].unique())), yticklabels = sorted(list(res_df['emotion'].unique())))
# Out:
# <Axes: >

# %%
cm_gem = confusion_matrix(res_df_gemma['emotion'],res_df_gemma['labelG'])
sns.heatmap(cm_gem, annot=True, fmt='d', cmap='Blues', xticklabels = sorted(list(res_df_gemma['emotion'].unique())), yticklabels = sorted(list(res_df_gemma['emotion'].unique())))
# Out:
# <Axes: >

# %%
cm_qwen = confusion_matrix(res_df_qwen['emotion'],res_df_qwen['labelQ'])
sns.heatmap(cm_qwen, annot=True, fmt='d', cmap='Blues', xticklabels = sorted(list(res_df_qwen['emotion'].unique())), yticklabels = sorted(list(res_df_qwen['emotion'].unique())))
# Out:
# <Axes: >

# %%
from sklearn.metrics import accuracy_score, brier_score_loss, classification_report
print(classification_report(res_df['emotion'], res_df['labelF'], zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.00      0.00      0.00         7
#      Disgust       0.00      0.00      0.00         7
#         Fear       0.20      0.14      0.17         7
#        Happy       0.29      0.50      0.36         4
#      Neutral       0.08      0.25      0.12         4
#          Sad       0.33      0.60      0.43         5
#     Surprise       0.00      0.00      0.00         5
#
#     accuracy                           0.18        39
#    macro avg       0.13      0.21      0.15        39
# weighted avg       0.12      0.18      0.13        39

# %%
print(classification_report(res_df_gemma['emotion'], res_df_gemma['labelG'], zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       1.00      0.43      0.60         7
#      Disgust       0.00      0.00      0.00         7
#         Fear       0.00      0.00      0.00         7
#        Happy       1.00      0.50      0.67         4
#      Neutral       0.15      0.75      0.25         4
#          Sad       0.00      0.00      0.00         5
#     Surprise       0.36      0.80      0.50         5
#
#     accuracy                           0.31        39
#    macro avg       0.36      0.35      0.29        39
# weighted avg       0.34      0.31      0.27        39

# %%
print(classification_report(res_df_qwen['emotion'], res_df_qwen['labelQ'], zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.50      0.71      0.59         7
#      Disgust       1.00      0.14      0.25         7
#         Fear       0.00      0.00      0.00         7
#        Happy       0.80      1.00      0.89         4
#      Neutral       0.29      1.00      0.44         4
#          Sad       1.00      0.20      0.33         5
#     Surprise       0.29      0.40      0.33         5
#
#     accuracy                           0.44        39
#    macro avg       0.55      0.49      0.41        39
# weighted avg       0.55      0.44      0.37        39

# %%
df
# Out:
#        labelF    scoreF   photo_name emotion
# 0     Neutral  0.746008   0Angry.jpg   Angry
# 1         Sad  0.103266   0Angry.jpg   Angry
# 2        Fear  0.058445   0Angry.jpg   Angry
# 3       Happy  0.043354   0Angry.jpg   Angry
# 4       Angry  0.032512   0Angry.jpg   Angry
# ..        ...       ...          ...     ...
# 190  Surprise  0.699558  18Angry.jpg   Angry
# 191      Fear  0.167385  18Angry.jpg   Angry
# 192     Happy  0.060133  18Angry.jpg   Angry
# 193     Angry  0.034304  18Angry.jpg   Angry
# 194   Neutral  0.020072  18Angry.jpg   Angry
#
# [195 rows x 4 columns]

# %%
df['is_correct'] = (df['labelF'] == df['emotion']).astype(int)
df_gemma['is_correct'] = (df_gemma['labelG'] == df_gemma['emotion']).astype(int)
df_qwen_f['is_correct'] = (df_qwen_f['labelQ'] == df_qwen_f['emotion']).astype(int)
df_qwen_f
# Out:
#        labelQ  scoreQ   photo_name emotion  is_correct
# 0       Angry    0.45   0Angry.jpg   Angry           1
# 1     Neutral    0.32   0Angry.jpg   Angry           0
# 2         Sad    0.18   0Angry.jpg   Angry           0
# 3       Happy    0.05   0Angry.jpg   Angry           0
# 4    Surprise    0.85    0Fear.jpg    Fear           0
# ..        ...     ...          ...     ...         ...
# 157   Neutral    0.25  17Happy.jpg   Happy           0
# 158       Sad    0.10  17Happy.jpg   Happy           0
# 159     Angry    0.95  18Angry.jpg   Angry           1
# 160   Disgust    0.05  18Angry.jpg   Angry           0
# 161      Fear    0.01  18Angry.jpg   Angry           0
#
# [162 rows x 5 columns]

# %%
scores = []
for photo_name in df['photo_name'].unique():
    temp = df[df['photo_name'] == photo_name]
    # Истинные метки (one-hot)
    y_true_binary = temp['is_correct'].values
    # Предсказанные вероятности
    y_prob = temp['scoreF'].values
    # Brier Score
    bs = np.mean((y_prob - y_true_binary) ** 2)
    scores.append(bs)
brier_score_facial = np.mean(scores)
scores_gemma = []
for photo_name in df_gemma['photo_name'].unique():
    temp_gemma = df_gemma[df_gemma['photo_name'] == photo_name]
    # Истинные метки (one-hot)
    y_true_binary_gemma = temp_gemma['is_correct'].values
    # Предсказанные вероятности
    y_prob_gemma = temp_gemma['scoreG'].values
    # Brier Score
    bs_gemma = np.mean((y_prob_gemma - y_true_binary_gemma) ** 2)
    scores_gemma.append(bs_gemma)
brier_score_gemma = np.mean(scores_gemma)
scores_qwen = []
for photo_name in df_qwen_f['photo_name'].unique():
    temp_qwen = df_qwen_f[df_qwen_f['photo_name'] == photo_name]
    # Истинные метки (one-hot)
    y_true_binary_qwen = temp_qwen['is_correct'].values
    # Предсказанные вероятности
    y_prob_qwen = temp_qwen['scoreQ'].values
    # Brier Score
    bs_qwen = np.mean((y_prob_qwen - y_true_binary_qwen) ** 2)
    scores_qwen.append(bs_qwen)
brier_score_qwen = np.mean(scores_qwen)
print(f"facial model: {brier_score_facial}\ngemma: {brier_score_gemma}\nqwen: {brier_score_qwen}")
# Out:
# facial model: 0.1549180080479835
# gemma: 0.1820535897435897
# qwen: 0.13028324786324783
